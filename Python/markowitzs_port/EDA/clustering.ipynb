# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', family='NanumGothic')
plt.rcParams["font.size"] = 12
plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams['xtick.labelsize'] = 12.
plt.rcParams['ytick.labelsize'] = 12.
from datetime import datetime
from datetime import timedelta
from pandas import Series, DataFrame
from sklearn.preprocessing import MinMaxScaler
from __future__ import print_function
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import math
import seaborn as sns
from sklearn import datasets

# %%
import os
path_dir = "archive2"
file_list = os.listdir(path_dir)

# %%
# 모든 ETF를 불러서 저장할 n 개의 데이터 프레임 빈공간 생성
# 밑에서 채워 넣을 것
etfs = [[] for i in range(0,len(file_list))]

# %%
# ETF 로드해서 각 자리에 채워넣기
for i in range(0, len(file_list)):
    file_name = path_dir + '/' + file_list[i]
    etfs[i] = pd.read_csv(file_name, delimiter=',')

# %%
# info()로 확인한 결과 Date 칼럼이 문자열(string)로 되어있음
# 계산과 순서의 편의성을 위해 문자열을 날짜 형식으로 전환
for i in range(0, len(file_list)):
    etfs[i]['Date']=etfs[i]['Date'].apply(lambda x: pd.to_datetime(str(x), format='%b %d, %Y')).copy()

# %%
# 잘 되었나 확인
etfs[0]
# Out:
#           Date  Price   Open   High    Low     Vol. Change %
# 0   2020-08-31  12.38  12.82  12.88  12.29    2.06M   -3.96%
# 1   2020-08-30  12.89  12.89  12.89  12.89        -    0.00%
# 2   2020-08-28  12.89  12.85  12.94  12.54    2.07M    2.46%
# 3   2020-08-27  12.58  12.55  13.15  12.45    3.19M    2.36%
# 4   2020-08-26  12.29  12.44  12.44  12.11    2.16M   -2.69%
# ..         ...    ...    ...    ...    ...      ...      ...
# 183 2020-01-08  63.50  65.46  65.46  63.40  117.86K   -1.92%
# 184 2020-01-07  64.74  64.00  65.46  62.57  100.49K    1.20%
# 185 2020-01-06  63.97  65.18  65.18  62.76  119.83K    0.41%
# 186 2020-01-03  63.71  64.08  64.08  61.42  164.12K    3.31%
# 187 2020-01-02  61.67  58.61  61.67  58.54   77.06K    7.14%
#
# [188 rows x 7 columns]

# %%
# 데이터 전처리, JDST ETF는 20에서 1000까지 오르거나 일일 변동이 300에서 1020까지 변동폭이 너무 넓음
# 따라서 이상치, 혹은 투기의 성격이 강하다 판단하고 판단에서 제외하였음

# %%
# 덮어씌우면 다시 불러오기 힘드니까 단계별로 각각 새로운 자료를 만들면서 작업
etfs_mod = [[] for i in range(0,len(file_list))]
etfs_temp = [[] for i in range(0,len(file_list))]
etfs_trans = [[] for i in range(0,len(file_list))]

# ETF들의 이름, 나중에 찾기 쉽도록
names = [[] for i in range(0,len(file_list))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35c785f24685> in <module>
#       1 # 덮어씌우면 다시 불러오기 힘드니까 단계별로 각각 새로운 자료를 만들면서 작업
# ----> 2 etfs_mod = [[] for i in range(0,len(file_list))]
#       3 etfs_temp = [[] for i in range(0,len(file_list))]
#       4 etfs_trans = [[] for i in range(0,len(file_list))]
#       5
#
# NameError: name 'file_list' is not defined

# %%
etfs[1][etfs[1]['Date'] >='2020-04-01']
# Out:
#           Date   Price    Open    High     Low    Vol. Change %
# 0   2020-08-31  284.28  286.20  286.31  283.93   4.07M   -0.84%
# 1   2020-08-30  286.70  286.70  286.70  286.70       -    0.00%
# 2   2020-08-28  286.70  286.23  287.45  285.00   2.72M    0.58%
# 3   2020-08-27  285.04  284.40  286.45  283.83   3.43M    0.57%
# 4   2020-08-26  283.43  282.58  283.60  281.60   2.65M    0.29%
# ..         ...     ...     ...     ...     ...     ...      ...
# 117 2020-04-07  226.60  235.46  236.16  226.45  10.86M    0.03%
# 118 2020-04-06  226.53  218.95  227.91  218.12  10.32M    7.56%
# 119 2020-04-03  210.60  212.73  214.55  208.69   6.66M   -1.57%
# 120 2020-04-02  213.96  208.31  214.79  207.18   8.23M    2.19%
# 121 2020-04-01  209.38  210.65  214.78  207.77   8.57M   -4.49%
#
# [122 rows x 7 columns]

# %%
# 전처리, 필요없는 칼럼 지우기, 숫자로 전환하기 쉽게 콤마 지우기
for i in range(0, len(file_list)):
#    etfs_mod[i] = etfs[i][etfs[i]['Date'] >='2020-04-01'].copy()
    etfs_mod[i] = etfs[i].copy()
    etfs_mod[i].drop(axis=1, columns= ['Open', 'Price','Low','Vol.','Change %'], inplace=True)
    etfs_mod[i]['High'] = etfs_mod[i]['High'].replace(',','')

# %%
# 날짜를 인덱스로 사용하기
for i in range(0, len(file_list)):
    etfs_temp[i] = etfs_mod[i].set_index('Date')

# %%
# 각 데이터 프레임에 해당하는 etf의 이름 붙여서 찾기 쉽게 하기
for i in range(0, len(file_list)):
    names[i] = file_list[i].split(' ')[0]
    etfs_temp[i].rename(columns={'High' : file_list[i]}, inplace=True)
    etfs_mod[i].rename(columns={'High' : file_list[i]}, inplace=True)

# %%
# 0,1로 스케일하기 위해서 스케일러 준비
scaler = MinMaxScaler()

# %%
# 리스케일하기
# 0,1 사이는 보기가 힘드니까 10배 곱해서 0,10 사이로 한다.
for i in range(0, len(file_list)):
    temp = scaler.fit_transform(etfs_temp[i])*10
    etfs_temp[i][file_list[i]] = temp

# %%
# 잘 되었나 확인
etfs_temp[8]
# Out:
#             EZU Historical Data.csv
# Date
# 2020-08-31                 8.374761
# 2020-08-30                 8.368388
# 2020-08-28                 8.374761
# 2020-08-27                 8.514978
# 2020-08-26                 8.508604
# ...                             ...
# 2020-01-08                 9.751434
# 2020-01-07                 9.630338
# 2020-01-06                 9.700446
# 2020-01-03                 9.745061
# 2020-01-02                10.000000
#
# [184 rows x 1 columns]

# %%
# 군집을 돌리려면 자료의 형태가 아래와 같아야 하므로, 행열바꾸기 transpose()
for i in range(0, len(file_list)):
    etfs_trans[i] = etfs_temp[i].transpose()

# %%
# 잘 되었나 확인
# 이런 자료가 44개 있음
etfs_trans[1]
# Out:
# Date                     2020-08-31  2020-08-30  2020-08-28  2020-08-27  \
# DIA Historical Data.csv    9.086653    9.123913    9.195567    9.100029
#
# Date                     2020-08-26  2020-08-25  2020-08-24  2020-08-23  \
# DIA Historical Data.csv    8.827744    8.873603    8.787618    8.415974
#
# Date                     2020-08-21  2020-08-20  ...  2020-01-15  2020-01-14  \
# DIA Historical Data.csv    8.446546    8.322346  ...    9.557657    9.486004
#
# Date                     2020-01-13  2020-01-10  2020-01-09  2020-01-08  \
# DIA Historical Data.csv    9.351295    9.443011    9.423904    9.312124
#
# Date                     2020-01-07  2020-01-06  2020-01-03  2020-01-02
# DIA Historical Data.csv    9.132512    9.155441    9.163084    9.308302
#
# [1 rows x 188 columns]

# %%
# 44개의 자료를 한 곳에 모을 빈 데이터프레임 준비
df = pd.DataFrame()

# %%
# 자료 모으기
for i in range(0, len(file_list)):
    df = pd.concat([df, etfs_trans[i]], axis = 0)

# %%
# 잘 모아졌나 확인
df
# Out:
# Date                      2020-01-02  2020-01-03  2020-01-06  2020-01-07  \
# DFEN Historical Data.csv    8.383854    8.750952    8.918507    8.961158
# DIA Historical Data.csv     9.308302    9.163084    9.155441    9.132512
# EEM Historical Data.csv     9.643799    9.300792    9.043536    9.063325
# EFA Historical Data.csv     9.888746    9.691913    9.636286    9.623449
# EWG Historical Data.csv     9.478827    9.128664    9.063518    9.071661
# EWH Historical Data.csv     9.016620    8.822715    8.628809    8.656510
# EWJ Historical Data.csv     9.929802    9.725590    9.604340    9.802170
# EWZ Historical Data.csv    10.000000    9.921348    9.741573    9.606742
# EZU Historical Data.csv    10.000000    9.745061    9.700446    9.630338
# FAS Historical Data.csv     8.691486    8.604472    8.514154    8.473400
# FAZ Historical Data.csv     2.265758    2.333901    2.371070    2.352486
# FXI Historical Data.csv     9.108392    8.557692    8.452797    8.426573
# GDX Historical Data.csv     4.002987    4.058999    4.025392    3.928305
# GDXJ Historical Data.csv    4.768106    4.811515    4.736121    4.690427
# IEFA Historical Data.csv    9.912924    9.715857    9.651696    9.647113
# IEMG Historical Data.csv    9.687332    9.342318    9.083558    9.099730
# IJR Historical Data.csv     9.576646    9.449364    9.435529    9.363586
# ITB Historical Data.csv     6.051972    6.017533    6.158422    6.174076
# IVV Historical Data.csv     7.825014    7.721404    7.727983    7.714004
# IWM Historical Data.csv     9.449104    9.255350    9.274147    9.245228
# KRE Historical Data.csv    10.000000    9.835656    9.632011    9.549839
# PSQ Historical Data.csv     6.161103    6.211901    6.298984    6.081277
# QID Historical Data.csv     6.162441    6.218307    6.321444    6.076493
# SDOW Historical Data.csv    2.625316    2.667089    2.725316    2.653165
# SDS Historical Data.csv     3.349153    3.420339    3.457627    3.362712
# SH Historical Data.csv      3.203240    3.284242    3.321060    3.217968
# SPXL Historical Data.csv    8.528229    8.390142    8.388394    8.372662
# SPXS Historical Data.csv    3.365792    3.437765    3.475868    3.378493
# SPXU Historical Data.csv    3.358501    3.425615    3.464765    3.369687
# SPY Historical Data.csv     7.846644    7.744570    7.751919    7.736404
# SRTY Historical Data.csv    2.025920    2.060225    2.069754    2.027825
# TECS Historical Data.csv    0.316779    0.328329    0.356377    0.313480
# TNA Historical Data.csv     9.306166    9.048629    9.065293    9.021360
# TZA Historical Data.csv     2.001549    2.037378    2.047061    2.005423
# UPRO Historical Data.csv    8.520720    8.383688    8.388641    8.367178
# USMV Historical Data.csv    8.208469    8.147976    8.129362    8.101443
# VEA Historical Data.csv     9.849279    9.665793    9.606815    9.606815
# VWO Historical Data.csv     9.739130    9.404682    9.150502    9.170569
# XLB Historical Data.csv     9.114031    8.478169    8.219585    8.206867
# XLE Historical Data.csv     9.822321   10.000000    9.963909    9.850083
# XLF Historical Data.csv     9.765258    9.608764    9.507042    9.475743
# XLI Historical Data.csv     9.327536    9.310145    9.292754    9.330435
# XLK Historical Data.csv     4.150765    4.073304    4.012847    4.071415
# XLP Historical Data.csv     8.241402    7.949384    7.910448    7.774173
# XLU Historical Data.csv     7.344207    7.101631    7.109996    7.005437
# XLV Historical Data.csv     7.872620    7.718319    7.744583    7.698621
# XOP Historical Data.csv     9.795305    9.995550    9.942152   10.000000
# XRT Historical Data.csv     7.312037    6.903000    6.926373    6.977016
#
# Date                      2020-01-08  2020-01-09  2020-01-10  2020-01-13  \
# DFEN Historical Data.csv    8.961158    8.993145    8.903275    8.792079
# DIA Historical Data.csv     9.312124    9.423904    9.443011    9.351295
# EEM Historical Data.csv     9.327177    9.445910    9.637203   10.000000
# EFA Historical Data.csv     9.709029    9.713308    9.726145    9.756098
# EWG Historical Data.csv     9.283388    9.446254    9.486971    9.438111
# EWH Historical Data.csv     8.795014    9.127424    9.279778    9.764543
# EWJ Historical Data.csv     9.795788    9.936184    9.859604    9.878749
# EWZ Historical Data.csv     9.655431    9.445693    9.558052    9.374532
# EZU Historical Data.csv     9.751434    9.770554    9.783301    9.783301
# FAS Historical Data.csv     8.650732    8.744355    8.774094    8.897456
# FAZ Historical Data.csv     2.346291    2.220846    2.234784    2.205359
# FXI Historical Data.csv     8.522727    8.697552    8.881119    9.466783
# GDX Historical Data.csv     3.894698    3.517550    3.569828    3.480209
# GDXJ Historical Data.csv    4.644734    4.288325    4.343157    4.219785
# IEFA Historical Data.csv    9.720440    9.725023    9.729606    9.766269
# IEMG Historical Data.csv    9.347709    9.460916    9.649596   10.000000
# IJR Historical Data.csv     9.429994    9.432761    9.330382    9.421693
# ITB Historical Data.csv     6.415153    6.343143    6.377583    6.408892
# IVV Historical Data.csv     7.898199    7.977140    8.037168    8.080750
# IWM Historical Data.csv     9.344997    9.405726    9.295836    9.346443
# KRE Historical Data.csv     9.685602    9.742765    9.660593    9.560557
# PSQ Historical Data.csv     6.066763    5.856313    5.827286    5.747460
# QID Historical Data.csv     6.050709    5.818651    5.792866    5.711216
# SDOW Historical Data.csv    2.675949    2.516456    2.543038    2.527848
# SDS Historical Data.csv     3.338983    3.193220    3.210169    3.176271
# SH Historical Data.csv      3.195876    3.048601    3.070692    3.026510
# SPXL Historical Data.csv    8.610383    8.715260    8.790421    8.851599
# SPXS Historical Data.csv    3.361558    3.213378    3.230313    3.196444
# SPXU Historical Data.csv    3.347315    3.201902    3.218680    3.185123
# SPY Historical Data.csv     7.919321    7.996897    8.056508    8.097338
# SRTY Historical Data.csv    1.997332    1.964932    2.029731    2.039261
# TECS Historical Data.csv    0.310180    0.257383    0.247484    0.227685
# TNA Historical Data.csv     9.150129    9.230420    9.077413    9.144069
# TZA Historical Data.csv     1.974436    1.943449    2.009296    2.018011
# UPRO Historical Data.csv    8.606571    8.708932    8.788179    8.841010
# USMV Historical Data.csv    8.185202    8.268962    8.329456    8.422522
# VEA Historical Data.csv     9.678899    9.692005    9.718218    9.770642
# VWO Historical Data.csv     9.404682    9.491639    9.672241   10.000000
# XLB Historical Data.csv     8.223824    8.257736    8.338279    8.448495
# XLE Historical Data.csv     9.836202    9.694614    9.683509    9.639089
# XLF Historical Data.csv     9.624413    9.687011    9.663537    9.647887
# XLI Historical Data.csv     9.428986    9.449275    9.472464    9.475362
# XLK Historical Data.csv     4.250897    4.385037    4.475723    4.575855
# XLP Historical Data.csv     7.865023    7.988319    8.079169    8.228423
# XLU Historical Data.csv     7.097449    7.156002    7.289837    7.440402
# XLV Historical Data.csv     8.036770    8.122127    8.214051    8.102429
# XOP Historical Data.csv     9.991100    9.570586    9.514963    9.394816
# XRT Historical Data.csv     7.015972    6.906895    6.793923    6.864044
#
# Date                      2020-01-14  2020-01-15  ...  2020-08-21  2020-08-22  \
# DFEN Historical Data.csv    8.853008    8.936786  ...    0.837776         NaN
# DIA Historical Data.csv     9.486004    9.557657  ...    8.446546         NaN
# EEM Historical Data.csv     9.835092    9.736148  ...    8.660950    8.654354
# EFA Historical Data.csv     9.820282    9.816003  ...    7.436885    7.432606
# EWG Historical Data.csv     9.454397    9.405537  ...    9.144951    9.136808
# EWH Historical Data.csv     9.778393    9.667590  ...    5.429363    5.332410
# EWJ Historical Data.csv     9.923421    9.776643  ...    8.455648    8.430121
# EWZ Historical Data.csv     9.404494    9.232210  ...    2.947566    2.947566
# EZU Historical Data.csv     9.776928    9.764181  ...    7.718292         NaN
# FAS Historical Data.csv     8.962441    8.887543  ...    2.163234         NaN
# FAZ Historical Data.csv     2.166641    2.188323  ...    0.291157         NaN
# FXI Historical Data.csv     9.108392    8.951049  ...    8.522727         NaN
# GDX Historical Data.csv     3.476475    3.681852  ...    8.327110         NaN
# GDXJ Historical Data.csv    4.224355    4.429975  ...    8.160841         NaN
# IEFA Historical Data.csv    9.821265    9.825848  ...    7.552704         NaN
# IEMG Historical Data.csv    9.843666    9.773585  ...    8.646900         NaN
# IJR Historical Data.csv     9.634754    9.676259  ...    6.726619         NaN
# ITB Historical Data.csv     6.534126    6.762680  ...    9.827802         NaN
# IVV Historical Data.csv     8.133377    8.167914  ...    9.036263         NaN
# IWM Historical Data.csv     9.570561    9.622614  ...    7.839792    7.693754
# KRE Historical Data.csv     9.721329    9.492676  ...    2.804573         NaN
# PSQ Historical Data.csv     5.689405    5.718433  ...    0.558781         NaN
# QID Historical Data.csv     5.638161    5.663945  ...    0.378169         NaN
# SDOW Historical Data.csv    2.501266    2.491139  ...    0.246835         NaN
# SDS Historical Data.csv     3.128814    3.108475  ...    0.403390         NaN
# SH Historical Data.csv      2.982327    2.960236  ...    0.567010         NaN
# SPXL Historical Data.csv    8.918021    8.959972  ...    6.317077    6.294354
# SPXS Historical Data.csv    3.149873    3.128704  ...    0.275191    0.228620
# SPXU Historical Data.csv    3.137584    3.120805  ...    0.268456    0.226510
# SPY Historical Data.csv     8.151233    8.183897  ...    9.053569    9.038053
# SRTY Historical Data.csv    1.982085    1.909663  ...    0.108634         NaN
# TECS Historical Data.csv    0.221086    0.224385  ...    1.522851         NaN
# TNA Historical Data.csv     9.444024    9.516740  ...    3.440388         NaN
# TZA Historical Data.csv     1.960879    1.889222  ...    0.107485         NaN
# UPRO Historical Data.csv    8.910352    8.956579  ...    6.333168         NaN
# USMV Historical Data.csv    8.422522    8.678455  ...    7.319684         NaN
# VEA Historical Data.csv     9.816514    9.816514  ...    7.863696         NaN
# VWO Historical Data.csv     9.839465    9.779264  ...    8.715719    8.695652
# XLB Historical Data.csv     8.490886    8.626537  ...    9.139466    9.092836
# XLE Historical Data.csv     9.611327    9.569684  ...    3.026097    2.981677
# XLF Historical Data.csv     9.765258    9.538341  ...    4.640063         NaN
# XLI Historical Data.csv     9.608696    9.591304  ...    7.486957         NaN
# XLK Historical Data.csv     4.594748    4.577744  ...    8.813527         NaN
# XLP Historical Data.csv     8.254380    8.611291  ...    9.078520         NaN
# XLU Historical Data.csv     7.448766    7.867001  ...    5.161020         NaN
# XLV Historical Data.csv     8.131976    8.506238  ...    9.405778         NaN
# XOP Historical Data.csv     9.457114    9.328068  ...    4.942708         NaN
# XRT Historical Data.csv     7.023763    6.918582  ...    9.509155         NaN
#
# Date                      2020-08-23  2020-08-24  2020-08-25  2020-08-26  \
# DFEN Historical Data.csv    0.790556    0.964204    0.988576    0.884996
# DIA Historical Data.csv     8.415974    8.787618    8.873603    8.827744
# EEM Historical Data.csv     8.654354    9.102902    9.300792    9.379947
# EFA Historical Data.csv     7.432606    7.851947    7.950364    8.005991
# EWG Historical Data.csv     9.136808    9.641694    9.837134   10.000000
# EWH Historical Data.csv     5.332410    5.927978    6.038781    5.941828
# EWJ Historical Data.csv     8.430121    8.851308    8.895980    8.947033
# EWZ Historical Data.csv     2.947566    3.071161    3.176030    3.183521
# EZU Historical Data.csv     7.711918    8.234544    8.444869    8.508604
# FAS Historical Data.csv     2.097147    2.305320    2.391233    2.358189
# FAZ Historical Data.csv     0.271024    0.255537    0.162614    0.161066
# FXI Historical Data.csv     8.461538    9.055944    9.064685    9.047203
# GDX Historical Data.csv     8.174010    8.431665    8.061987    8.450336
# GDXJ Historical Data.csv    8.003199    8.286498    7.939228    8.359607
# IEFA Historical Data.csv    7.548121    7.951421    8.056829    8.139322
# IEMG Historical Data.csv    8.619946    9.078167    9.266846    9.342318
# IJR Historical Data.csv     6.593802    6.961815    7.061428    6.983951
# ITB Historical Data.csv     9.796493   10.000000    9.965560    9.843456
# IVV Historical Data.csv     9.019817    9.307623    9.406299    9.710550
# IWM Historical Data.csv     7.693754    7.927993    8.001735    8.006073
# KRE Historical Data.csv     2.608074    3.179707    3.483387    3.204716
# PSQ Historical Data.csv     0.457184    0.471698    0.428157    0.232221
# QID Historical Data.csv     0.309411    0.322303    0.287924    0.159003
# SDOW Historical Data.csv    0.179747    0.154430    0.137975    0.124051
# SDS Historical Data.csv     0.342373    0.288136    0.250847    0.189831
# SH Historical Data.csv      0.478645    0.405007    0.353461    0.272459
# SPXL Historical Data.csv    6.294354    6.593253    6.701626    7.024996
# SPXS Historical Data.csv    0.228620    0.198984    0.169348    0.131245
# SPXU Historical Data.csv    0.226510    0.192953    0.164989    0.125839
# SPY Historical Data.csv     9.038053    9.322228    9.418586    9.721542
# SRTY Historical Data.csv    0.076234    0.083857    0.068611    0.057176
# TECS Historical Data.csv    1.435407    1.433757    1.402409    1.288566
# TNA Historical Data.csv     3.337373    3.499470    3.557037    3.549462
# TZA Historical Data.csv     0.076498    0.084245    0.068752    0.057132
# UPRO Historical Data.csv    6.316658    6.612184    6.721149    7.043091
# USMV Historical Data.csv    7.287110    7.477897    7.566310    7.650070
# VEA Historical Data.csv     7.857143    8.237221    8.342071    8.460026
# VWO Historical Data.csv     8.695652    9.110368    9.270903    9.324415
# XLB Historical Data.csv     9.092836    9.559135    9.728699    9.775329
# XLE Historical Data.csv     2.981677    3.325930    3.320378    3.095502
# XLF Historical Data.csv     4.467919    4.921753    5.140845    4.968701
# XLI Historical Data.csv     7.426087    7.826087    7.979710    7.886957
# XLK Historical Data.csv     8.788967    9.113924    9.100699    9.614585
# XLP Historical Data.csv     9.020117    9.377028    9.480857    9.396496
# XLU Historical Data.csv     5.115015    5.336679    5.374320    5.006274
# XLV Historical Data.csv     9.359816    9.530532    9.448457    9.432042
# XOP Historical Data.csv     4.862610    5.102904    5.130715    5.035043
# XRT Historical Data.csv     9.423451    9.781847    9.703935    9.914297
#
# Date                      2020-08-27  2020-08-28  2020-08-30  2020-08-31
# DFEN Historical Data.csv    0.993145    0.961158    0.953542    0.952018
# DIA Historical Data.csv     9.100029    9.195567    9.123913    9.086653
# EEM Historical Data.csv     9.426121    9.498681    9.492084    8.918206
# EFA Historical Data.csv     8.001712    7.899016    7.886179    7.903295
# EWG Historical Data.csv     9.967427    9.796417    9.788274    9.910423
# EWH Historical Data.csv     5.706371    6.260388    6.218837    6.052632
# EWJ Historical Data.csv     8.832163    8.749202    8.742821    8.825782
# EWZ Historical Data.csv     3.011236    3.411985    3.411985    3.209738
# EZU Historical Data.csv     8.514978    8.374761    8.368388    8.374761
# FAS Historical Data.csv     2.560855    2.612623    2.599405    2.588391
# FAZ Historical Data.csv     0.128543    0.060400    0.000000    0.071241
# FXI Historical Data.csv     9.073427    9.222028    9.204545    8.426573
# GDX Historical Data.csv     8.704257    8.674384    8.573562    8.890963
# GDXJ Historical Data.csv    8.608636    8.642906    8.594928    8.853096
# IEFA Historical Data.csv    8.134739    8.038497    8.038497    8.056829
# IEMG Historical Data.csv    9.380054    9.471698    9.455526    8.932615
# IJR Historical Data.csv     7.036525    7.000553    7.000553    6.978417
# ITB Historical Data.csv     9.793363    9.624296    9.392611    9.464621
# IVV Historical Data.csv     9.880766    9.952307    9.936683   10.000000
# IWM Historical Data.csv     8.034991    8.068248    8.056680    8.092828
# KRE Historical Data.csv     3.319043    3.340479    3.161844    3.151125
# PSQ Historical Data.csv     0.152395    0.065312    0.014514    0.000000
# QID Historical Data.csv     0.103137    0.047271    0.004297    0.000000
# SDOW Historical Data.csv    0.073418    0.044304    0.000000    0.067089
# SDS Historical Data.csv     0.118644    0.071186    0.000000    0.040678
# SH Historical Data.csv      0.162003    0.103093    0.000000    0.058910
# SPXL Historical Data.csv    7.208530    7.280196    7.269708    7.329138
# SPXS Historical Data.csv    0.084674    0.055038    0.000000    0.029636
# SPXU Historical Data.csv    0.078300    0.047539    0.000000    0.025168
# SPY Historical Data.csv     9.888127    9.955904    9.944472   10.000000
# SRTY Historical Data.csv    0.074328    0.040023    0.000000    0.051458
# TECS Historical Data.csv    1.258868    1.187923    1.148325    1.163174
# TNA Historical Data.csv     3.569156    3.588850    3.579761    3.607029
# TZA Historical Data.csv     0.074562    0.041638    0.000000    0.051322
# UPRO Historical Data.csv    7.223048    7.302295    7.289087    7.351824
# USMV Historical Data.csv    7.864123    7.896696    7.892043    7.938576
# VEA Historical Data.csv     8.453473    8.368283    8.355177    8.335518
# VWO Historical Data.csv     9.404682    9.498328    9.478261    8.963211
# XLB Historical Data.csv     9.868588   10.000000    9.974565    9.978805
# XLE Historical Data.csv     2.981677    3.126041    3.095502    3.120489
# XLF Historical Data.csv     5.297340    5.359937    5.289515    5.273865
# XLI Historical Data.csv     8.078261    8.115942    8.104348    8.121739
# XLK Historical Data.csv     9.756282    9.850746    9.775175   10.000000
# XLP Historical Data.csv     9.798832   10.000000    9.974043    9.974043
# XLU Historical Data.csv     5.069009    4.993726    4.968632    5.194479
# XLV Historical Data.csv     9.832567    9.766907    9.747209   10.000000
# XOP Historical Data.csv     4.941595    5.027256    5.003894    5.013906
# XRT Historical Data.csv    10.000000    9.898714    9.657187    9.629918
#
# [48 rows x 189 columns]

# %%
# Nan(결측치)는 어떻게 처리할지 고민하다가, 8개월이나 자료가 있으니 Nan 있는 날짜는 과감하게 지워버림
df2 = df.dropna(axis=1)

# %%
# 히트맵 그리기 위해서 전처리
data = df2.transpose().corr()

# %%
# 일반적인 히트맵 그리기
plt.figure(figsize=(25,25))
sns.heatmap(data, annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# C:\Users\JIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\JIN\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 좀 더 예쁜 히트맵 그리기
fig, ax = plt.subplots( figsize=(20,20) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(data, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵을 그린다
sns.heatmap(data, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
# 군집분석을 위해 몇 개의 군집으로 나눌 지 계산한다.
# 약 4가 엘보 포인트라 가정하고 4로 나눈다.
ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(df2)
    inertias.append(model.inertia_)

plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters(K)')
plt.ylabel('SSE')
plt.xticks(ks)
plt.show()

# %%
# 군집분석 진행, 파라미터는 일단 야매로 간단하게 넣기
model = KMeans(n_clusters=3, init="random", n_init=1,
               max_iter=1000, random_state=1).fit(df2)

# %%
# 모델이 잘 학습되었나 확인
model
# Out:
# KMeans(init='random', max_iter=1000, n_clusters=3, n_init=1, random_state=1)

# %%
# 군집이 180개의 차원을 가지고 있음
# 2차원 그래프에 나타내려면 2개 차원으로 줄여야 함
# 차원축소는 결과는 예쁘게 나오지만, 알아먹기가 힘듦(차원들이 합성되므로)
# 임의의 새로운 차원을 만들고 표시하기로 함

clusters = df2.copy()

# 차원 1, 6개월간 평균 가격
clusters['Mean'] = clusters.mean(axis=1)

# 차원 2, 어제와 오늘의 변동량을 구하고 이것의 전체평균
# 0.01 등으로 수치가 작게 나오므로 보기 편하게 100 곱해준다.
clusters['Gap_Mean'] = abs(clusters.diff(axis=1).mean(axis=1))*100

# %%
# 오른쪽 맨 끝에 Mean, Gap_Mean이 예쁘게 들어갔나 확인
clusters
# Out:
# Date                      2020-01-02 00:00:00  2020-01-03 00:00:00  \
# DFEN Historical Data.csv             8.383854             8.750952
# DIA Historical Data.csv              9.308302             9.163084
# EEM Historical Data.csv              9.643799             9.300792
# EFA Historical Data.csv              9.888746             9.691913
# EWG Historical Data.csv              9.478827             9.128664
# EWH Historical Data.csv              9.016620             8.822715
# EWJ Historical Data.csv              9.929802             9.725590
# EWZ Historical Data.csv             10.000000             9.921348
# EZU Historical Data.csv             10.000000             9.745061
# FAS Historical Data.csv              8.691486             8.604472
# FAZ Historical Data.csv              2.265758             2.333901
# FXI Historical Data.csv              9.108392             8.557692
# GDX Historical Data.csv              4.002987             4.058999
# GDXJ Historical Data.csv             4.768106             4.811515
# IEFA Historical Data.csv             9.912924             9.715857
# IEMG Historical Data.csv             9.687332             9.342318
# IJR Historical Data.csv              9.576646             9.449364
# ITB Historical Data.csv              6.051972             6.017533
# IVV Historical Data.csv              7.825014             7.721404
# IWM Historical Data.csv              9.449104             9.255350
# KRE Historical Data.csv             10.000000             9.835656
# PSQ Historical Data.csv              6.161103             6.211901
# QID Historical Data.csv              6.162441             6.218307
# SDOW Historical Data.csv             2.625316             2.667089
# SDS Historical Data.csv              3.349153             3.420339
# SH Historical Data.csv               3.203240             3.284242
# SPXL Historical Data.csv             8.528229             8.390142
# SPXS Historical Data.csv             3.365792             3.437765
# SPXU Historical Data.csv             3.358501             3.425615
# SPY Historical Data.csv              7.846644             7.744570
# SRTY Historical Data.csv             2.025920             2.060225
# TECS Historical Data.csv             0.316779             0.328329
# TNA Historical Data.csv              9.306166             9.048629
# TZA Historical Data.csv              2.001549             2.037378
# UPRO Historical Data.csv             8.520720             8.383688
# USMV Historical Data.csv             8.208469             8.147976
# VEA Historical Data.csv              9.849279             9.665793
# VWO Historical Data.csv              9.739130             9.404682
# XLB Historical Data.csv              9.114031             8.478169
# XLE Historical Data.csv              9.822321            10.000000
# XLF Historical Data.csv              9.765258             9.608764
# XLI Historical Data.csv              9.327536             9.310145
# XLK Historical Data.csv              4.150765             4.073304
# XLP Historical Data.csv              8.241402             7.949384
# XLU Historical Data.csv              7.344207             7.101631
# XLV Historical Data.csv              7.872620             7.718319
# XOP Historical Data.csv              9.795305             9.995550
# XRT Historical Data.csv              7.312037             6.903000
#
# Date                      2020-01-06 00:00:00  2020-01-07 00:00:00  \
# DFEN Historical Data.csv             8.918507             8.961158
# DIA Historical Data.csv              9.155441             9.132512
# EEM Historical Data.csv              9.043536             9.063325
# EFA Historical Data.csv              9.636286             9.623449
# EWG Historical Data.csv              9.063518             9.071661
# EWH Historical Data.csv              8.628809             8.656510
# EWJ Historical Data.csv              9.604340             9.802170
# EWZ Historical Data.csv              9.741573             9.606742
# EZU Historical Data.csv              9.700446             9.630338
# FAS Historical Data.csv              8.514154             8.473400
# FAZ Historical Data.csv              2.371070             2.352486
# FXI Historical Data.csv              8.452797             8.426573
# GDX Historical Data.csv              4.025392             3.928305
# GDXJ Historical Data.csv             4.736121             4.690427
# IEFA Historical Data.csv             9.651696             9.647113
# IEMG Historical Data.csv             9.083558             9.099730
# IJR Historical Data.csv              9.435529             9.363586
# ITB Historical Data.csv              6.158422             6.174076
# IVV Historical Data.csv              7.727983             7.714004
# IWM Historical Data.csv              9.274147             9.245228
# KRE Historical Data.csv              9.632011             9.549839
# PSQ Historical Data.csv              6.298984             6.081277
# QID Historical Data.csv              6.321444             6.076493
# SDOW Historical Data.csv             2.725316             2.653165
# SDS Historical Data.csv              3.457627             3.362712
# SH Historical Data.csv               3.321060             3.217968
# SPXL Historical Data.csv             8.388394             8.372662
# SPXS Historical Data.csv             3.475868             3.378493
# SPXU Historical Data.csv             3.464765             3.369687
# SPY Historical Data.csv              7.751919             7.736404
# SRTY Historical Data.csv             2.069754             2.027825
# TECS Historical Data.csv             0.356377             0.313480
# TNA Historical Data.csv              9.065293             9.021360
# TZA Historical Data.csv              2.047061             2.005423
# UPRO Historical Data.csv             8.388641             8.367178
# USMV Historical Data.csv             8.129362             8.101443
# VEA Historical Data.csv              9.606815             9.606815
# VWO Historical Data.csv              9.150502             9.170569
# XLB Historical Data.csv              8.219585             8.206867
# XLE Historical Data.csv              9.963909             9.850083
# XLF Historical Data.csv              9.507042             9.475743
# XLI Historical Data.csv              9.292754             9.330435
# XLK Historical Data.csv              4.012847             4.071415
# XLP Historical Data.csv              7.910448             7.774173
# XLU Historical Data.csv              7.109996             7.005437
# XLV Historical Data.csv              7.744583             7.698621
# XOP Historical Data.csv              9.942152            10.000000
# XRT Historical Data.csv              6.926373             6.977016
#
# Date                      2020-01-08 00:00:00  2020-01-09 00:00:00  \
# DFEN Historical Data.csv             8.961158             8.993145
# DIA Historical Data.csv              9.312124             9.423904
# EEM Historical Data.csv              9.327177             9.445910
# EFA Historical Data.csv              9.709029             9.713308
# EWG Historical Data.csv              9.283388             9.446254
# EWH Historical Data.csv              8.795014             9.127424
# EWJ Historical Data.csv              9.795788             9.936184
# EWZ Historical Data.csv              9.655431             9.445693
# EZU Historical Data.csv              9.751434             9.770554
# FAS Historical Data.csv              8.650732             8.744355
# FAZ Historical Data.csv              2.346291             2.220846
# FXI Historical Data.csv              8.522727             8.697552
# GDX Historical Data.csv              3.894698             3.517550
# GDXJ Historical Data.csv             4.644734             4.288325
# IEFA Historical Data.csv             9.720440             9.725023
# IEMG Historical Data.csv             9.347709             9.460916
# IJR Historical Data.csv              9.429994             9.432761
# ITB Historical Data.csv              6.415153             6.343143
# IVV Historical Data.csv              7.898199             7.977140
# IWM Historical Data.csv              9.344997             9.405726
# KRE Historical Data.csv              9.685602             9.742765
# PSQ Historical Data.csv              6.066763             5.856313
# QID Historical Data.csv              6.050709             5.818651
# SDOW Historical Data.csv             2.675949             2.516456
# SDS Historical Data.csv              3.338983             3.193220
# SH Historical Data.csv               3.195876             3.048601
# SPXL Historical Data.csv             8.610383             8.715260
# SPXS Historical Data.csv             3.361558             3.213378
# SPXU Historical Data.csv             3.347315             3.201902
# SPY Historical Data.csv              7.919321             7.996897
# SRTY Historical Data.csv             1.997332             1.964932
# TECS Historical Data.csv             0.310180             0.257383
# TNA Historical Data.csv              9.150129             9.230420
# TZA Historical Data.csv              1.974436             1.943449
# UPRO Historical Data.csv             8.606571             8.708932
# USMV Historical Data.csv             8.185202             8.268962
# VEA Historical Data.csv              9.678899             9.692005
# VWO Historical Data.csv              9.404682             9.491639
# XLB Historical Data.csv              8.223824             8.257736
# XLE Historical Data.csv              9.836202             9.694614
# XLF Historical Data.csv              9.624413             9.687011
# XLI Historical Data.csv              9.428986             9.449275
# XLK Historical Data.csv              4.250897             4.385037
# XLP Historical Data.csv              7.865023             7.988319
# XLU Historical Data.csv              7.097449             7.156002
# XLV Historical Data.csv              8.036770             8.122127
# XOP Historical Data.csv              9.991100             9.570586
# XRT Historical Data.csv              7.015972             6.906895
#
# Date                      2020-01-10 00:00:00  2020-01-13 00:00:00  \
# DFEN Historical Data.csv             8.903275             8.792079
# DIA Historical Data.csv              9.443011             9.351295
# EEM Historical Data.csv              9.637203            10.000000
# EFA Historical Data.csv              9.726145             9.756098
# EWG Historical Data.csv              9.486971             9.438111
# EWH Historical Data.csv              9.279778             9.764543
# EWJ Historical Data.csv              9.859604             9.878749
# EWZ Historical Data.csv              9.558052             9.374532
# EZU Historical Data.csv              9.783301             9.783301
# FAS Historical Data.csv              8.774094             8.897456
# FAZ Historical Data.csv              2.234784             2.205359
# FXI Historical Data.csv              8.881119             9.466783
# GDX Historical Data.csv              3.569828             3.480209
# GDXJ Historical Data.csv             4.343157             4.219785
# IEFA Historical Data.csv             9.729606             9.766269
# IEMG Historical Data.csv             9.649596            10.000000
# IJR Historical Data.csv              9.330382             9.421693
# ITB Historical Data.csv              6.377583             6.408892
# IVV Historical Data.csv              8.037168             8.080750
# IWM Historical Data.csv              9.295836             9.346443
# KRE Historical Data.csv              9.660593             9.560557
# PSQ Historical Data.csv              5.827286             5.747460
# QID Historical Data.csv              5.792866             5.711216
# SDOW Historical Data.csv             2.543038             2.527848
# SDS Historical Data.csv              3.210169             3.176271
# SH Historical Data.csv               3.070692             3.026510
# SPXL Historical Data.csv             8.790421             8.851599
# SPXS Historical Data.csv             3.230313             3.196444
# SPXU Historical Data.csv             3.218680             3.185123
# SPY Historical Data.csv              8.056508             8.097338
# SRTY Historical Data.csv             2.029731             2.039261
# TECS Historical Data.csv             0.247484             0.227685
# TNA Historical Data.csv              9.077413             9.144069
# TZA Historical Data.csv              2.009296             2.018011
# UPRO Historical Data.csv             8.788179             8.841010
# USMV Historical Data.csv             8.329456             8.422522
# VEA Historical Data.csv              9.718218             9.770642
# VWO Historical Data.csv              9.672241            10.000000
# XLB Historical Data.csv              8.338279             8.448495
# XLE Historical Data.csv              9.683509             9.639089
# XLF Historical Data.csv              9.663537             9.647887
# XLI Historical Data.csv              9.472464             9.475362
# XLK Historical Data.csv              4.475723             4.575855
# XLP Historical Data.csv              8.079169             8.228423
# XLU Historical Data.csv              7.289837             7.440402
# XLV Historical Data.csv              8.214051             8.102429
# XOP Historical Data.csv              9.514963             9.394816
# XRT Historical Data.csv              6.793923             6.864044
#
# Date                      2020-01-14 00:00:00  2020-01-15 00:00:00  ...  \
# DFEN Historical Data.csv             8.853008             8.936786  ...
# DIA Historical Data.csv              9.486004             9.557657  ...
# EEM Historical Data.csv              9.835092             9.736148  ...
# EFA Historical Data.csv              9.820282             9.816003  ...
# EWG Historical Data.csv              9.454397             9.405537  ...
# EWH Historical Data.csv              9.778393             9.667590  ...
# EWJ Historical Data.csv              9.923421             9.776643  ...
# EWZ Historical Data.csv              9.404494             9.232210  ...
# EZU Historical Data.csv              9.776928             9.764181  ...
# FAS Historical Data.csv              8.962441             8.887543  ...
# FAZ Historical Data.csv              2.166641             2.188323  ...
# FXI Historical Data.csv              9.108392             8.951049  ...
# GDX Historical Data.csv              3.476475             3.681852  ...
# GDXJ Historical Data.csv             4.224355             4.429975  ...
# IEFA Historical Data.csv             9.821265             9.825848  ...
# IEMG Historical Data.csv             9.843666             9.773585  ...
# IJR Historical Data.csv              9.634754             9.676259  ...
# ITB Historical Data.csv              6.534126             6.762680  ...
# IVV Historical Data.csv              8.133377             8.167914  ...
# IWM Historical Data.csv              9.570561             9.622614  ...
# KRE Historical Data.csv              9.721329             9.492676  ...
# PSQ Historical Data.csv              5.689405             5.718433  ...
# QID Historical Data.csv              5.638161             5.663945  ...
# SDOW Historical Data.csv             2.501266             2.491139  ...
# SDS Historical Data.csv              3.128814             3.108475  ...
# SH Historical Data.csv               2.982327             2.960236  ...
# SPXL Historical Data.csv             8.918021             8.959972  ...
# SPXS Historical Data.csv             3.149873             3.128704  ...
# SPXU Historical Data.csv             3.137584             3.120805  ...
# SPY Historical Data.csv              8.151233             8.183897  ...
# SRTY Historical Data.csv             1.982085             1.909663  ...
# TECS Historical Data.csv             0.221086             0.224385  ...
# TNA Historical Data.csv              9.444024             9.516740  ...
# TZA Historical Data.csv              1.960879             1.889222  ...
# UPRO Historical Data.csv             8.910352             8.956579  ...
# USMV Historical Data.csv             8.422522             8.678455  ...
# VEA Historical Data.csv              9.816514             9.816514  ...
# VWO Historical Data.csv              9.839465             9.779264  ...
# XLB Historical Data.csv              8.490886             8.626537  ...
# XLE Historical Data.csv              9.611327             9.569684  ...
# XLF Historical Data.csv              9.765258             9.538341  ...
# XLI Historical Data.csv              9.608696             9.591304  ...
# XLK Historical Data.csv              4.594748             4.577744  ...
# XLP Historical Data.csv              8.254380             8.611291  ...
# XLU Historical Data.csv              7.448766             7.867001  ...
# XLV Historical Data.csv              8.131976             8.506238  ...
# XOP Historical Data.csv              9.457114             9.328068  ...
# XRT Historical Data.csv              7.023763             6.918582  ...
#
# Date                      2020-08-23 00:00:00  2020-08-24 00:00:00  \
# DFEN Historical Data.csv             0.790556             0.964204
# DIA Historical Data.csv              8.415974             8.787618
# EEM Historical Data.csv              8.654354             9.102902
# EFA Historical Data.csv              7.432606             7.851947
# EWG Historical Data.csv              9.136808             9.641694
# EWH Historical Data.csv              5.332410             5.927978
# EWJ Historical Data.csv              8.430121             8.851308
# EWZ Historical Data.csv              2.947566             3.071161
# EZU Historical Data.csv              7.711918             8.234544
# FAS Historical Data.csv              2.097147             2.305320
# FAZ Historical Data.csv              0.271024             0.255537
# FXI Historical Data.csv              8.461538             9.055944
# GDX Historical Data.csv              8.174010             8.431665
# GDXJ Historical Data.csv             8.003199             8.286498
# IEFA Historical Data.csv             7.548121             7.951421
# IEMG Historical Data.csv             8.619946             9.078167
# IJR Historical Data.csv              6.593802             6.961815
# ITB Historical Data.csv              9.796493            10.000000
# IVV Historical Data.csv              9.019817             9.307623
# IWM Historical Data.csv              7.693754             7.927993
# KRE Historical Data.csv              2.608074             3.179707
# PSQ Historical Data.csv              0.457184             0.471698
# QID Historical Data.csv              0.309411             0.322303
# SDOW Historical Data.csv             0.179747             0.154430
# SDS Historical Data.csv              0.342373             0.288136
# SH Historical Data.csv               0.478645             0.405007
# SPXL Historical Data.csv             6.294354             6.593253
# SPXS Historical Data.csv             0.228620             0.198984
# SPXU Historical Data.csv             0.226510             0.192953
# SPY Historical Data.csv              9.038053             9.322228
# SRTY Historical Data.csv             0.076234             0.083857
# TECS Historical Data.csv             1.435407             1.433757
# TNA Historical Data.csv              3.337373             3.499470
# TZA Historical Data.csv              0.076498             0.084245
# UPRO Historical Data.csv             6.316658             6.612184
# USMV Historical Data.csv             7.287110             7.477897
# VEA Historical Data.csv              7.857143             8.237221
# VWO Historical Data.csv              8.695652             9.110368
# XLB Historical Data.csv              9.092836             9.559135
# XLE Historical Data.csv              2.981677             3.325930
# XLF Historical Data.csv              4.467919             4.921753
# XLI Historical Data.csv              7.426087             7.826087
# XLK Historical Data.csv              8.788967             9.113924
# XLP Historical Data.csv              9.020117             9.377028
# XLU Historical Data.csv              5.115015             5.336679
# XLV Historical Data.csv              9.359816             9.530532
# XOP Historical Data.csv              4.862610             5.102904
# XRT Historical Data.csv              9.423451             9.781847
#
# Date                      2020-08-25 00:00:00  2020-08-26 00:00:00  \
# DFEN Historical Data.csv             0.988576             0.884996
# DIA Historical Data.csv              8.873603             8.827744
# EEM Historical Data.csv              9.300792             9.379947
# EFA Historical Data.csv              7.950364             8.005991
# EWG Historical Data.csv              9.837134            10.000000
# EWH Historical Data.csv              6.038781             5.941828
# EWJ Historical Data.csv              8.895980             8.947033
# EWZ Historical Data.csv              3.176030             3.183521
# EZU Historical Data.csv              8.444869             8.508604
# FAS Historical Data.csv              2.391233             2.358189
# FAZ Historical Data.csv              0.162614             0.161066
# FXI Historical Data.csv              9.064685             9.047203
# GDX Historical Data.csv              8.061987             8.450336
# GDXJ Historical Data.csv             7.939228             8.359607
# IEFA Historical Data.csv             8.056829             8.139322
# IEMG Historical Data.csv             9.266846             9.342318
# IJR Historical Data.csv              7.061428             6.983951
# ITB Historical Data.csv              9.965560             9.843456
# IVV Historical Data.csv              9.406299             9.710550
# IWM Historical Data.csv              8.001735             8.006073
# KRE Historical Data.csv              3.483387             3.204716
# PSQ Historical Data.csv              0.428157             0.232221
# QID Historical Data.csv              0.287924             0.159003
# SDOW Historical Data.csv             0.137975             0.124051
# SDS Historical Data.csv              0.250847             0.189831
# SH Historical Data.csv               0.353461             0.272459
# SPXL Historical Data.csv             6.701626             7.024996
# SPXS Historical Data.csv             0.169348             0.131245
# SPXU Historical Data.csv             0.164989             0.125839
# SPY Historical Data.csv              9.418586             9.721542
# SRTY Historical Data.csv             0.068611             0.057176
# TECS Historical Data.csv             1.402409             1.288566
# TNA Historical Data.csv              3.557037             3.549462
# TZA Historical Data.csv              0.068752             0.057132
# UPRO Historical Data.csv             6.721149             7.043091
# USMV Historical Data.csv             7.566310             7.650070
# VEA Historical Data.csv              8.342071             8.460026
# VWO Historical Data.csv              9.270903             9.324415
# XLB Historical Data.csv              9.728699             9.775329
# XLE Historical Data.csv              3.320378             3.095502
# XLF Historical Data.csv              5.140845             4.968701
# XLI Historical Data.csv              7.979710             7.886957
# XLK Historical Data.csv              9.100699             9.614585
# XLP Historical Data.csv              9.480857             9.396496
# XLU Historical Data.csv              5.374320             5.006274
# XLV Historical Data.csv              9.448457             9.432042
# XOP Historical Data.csv              5.130715             5.035043
# XRT Historical Data.csv              9.703935             9.914297
#
# Date                      2020-08-27 00:00:00  2020-08-28 00:00:00  \
# DFEN Historical Data.csv             0.993145             0.961158
# DIA Historical Data.csv              9.100029             9.195567
# EEM Historical Data.csv              9.426121             9.498681
# EFA Historical Data.csv              8.001712             7.899016
# EWG Historical Data.csv              9.967427             9.796417
# EWH Historical Data.csv              5.706371             6.260388
# EWJ Historical Data.csv              8.832163             8.749202
# EWZ Historical Data.csv              3.011236             3.411985
# EZU Historical Data.csv              8.514978             8.374761
# FAS Historical Data.csv              2.560855             2.612623
# FAZ Historical Data.csv              0.128543             0.060400
# FXI Historical Data.csv              9.073427             9.222028
# GDX Historical Data.csv              8.704257             8.674384
# GDXJ Historical Data.csv             8.608636             8.642906
# IEFA Historical Data.csv             8.134739             8.038497
# IEMG Historical Data.csv             9.380054             9.471698
# IJR Historical Data.csv              7.036525             7.000553
# ITB Historical Data.csv              9.793363             9.624296
# IVV Historical Data.csv              9.880766             9.952307
# IWM Historical Data.csv              8.034991             8.068248
# KRE Historical Data.csv              3.319043             3.340479
# PSQ Historical Data.csv              0.152395             0.065312
# QID Historical Data.csv              0.103137             0.047271
# SDOW Historical Data.csv             0.073418             0.044304
# SDS Historical Data.csv              0.118644             0.071186
# SH Historical Data.csv               0.162003             0.103093
# SPXL Historical Data.csv             7.208530             7.280196
# SPXS Historical Data.csv             0.084674             0.055038
# SPXU Historical Data.csv             0.078300             0.047539
# SPY Historical Data.csv              9.888127             9.955904
# SRTY Historical Data.csv             0.074328             0.040023
# TECS Historical Data.csv             1.258868             1.187923
# TNA Historical Data.csv              3.569156             3.588850
# TZA Historical Data.csv              0.074562             0.041638
# UPRO Historical Data.csv             7.223048             7.302295
# USMV Historical Data.csv             7.864123             7.896696
# VEA Historical Data.csv              8.453473             8.368283
# VWO Historical Data.csv              9.404682             9.498328
# XLB Historical Data.csv              9.868588            10.000000
# XLE Historical Data.csv              2.981677             3.126041
# XLF Historical Data.csv              5.297340             5.359937
# XLI Historical Data.csv              8.078261             8.115942
# XLK Historical Data.csv              9.756282             9.850746
# XLP Historical Data.csv              9.798832            10.000000
# XLU Historical Data.csv              5.069009             4.993726
# XLV Historical Data.csv              9.832567             9.766907
# XOP Historical Data.csv              4.941595             5.027256
# XRT Historical Data.csv             10.000000             9.898714
#
# Date                      2020-08-30 00:00:00  2020-08-31 00:00:00      Mean  \
# DFEN Historical Data.csv             0.953542             0.952018  2.814350
# DIA Historical Data.csv              9.123913             9.086653  6.770447
# EEM Historical Data.csv              9.492084             8.918206  6.343508
# EFA Historical Data.csv              7.886179             7.903295  6.336385
# EWG Historical Data.csv              9.788274             9.910423  6.939632
# EWH Historical Data.csv              6.218837             6.052632  5.014307
# EWJ Historical Data.csv              8.742821             8.825782  6.778649
# EWZ Historical Data.csv              3.411985             3.209738  3.973268
# EZU Historical Data.csv              8.368388             8.374761  6.370895
# FAS Historical Data.csv              2.599405             2.588391  3.423817
# FAZ Historical Data.csv              0.000000             0.071241  1.946673
# FXI Historical Data.csv              9.204545             8.426573  5.750788
# GDX Historical Data.csv              8.573562             8.890963  5.572348
# GDXJ Historical Data.csv             8.594928             8.853096  5.502251
# IEFA Historical Data.csv             8.038497             8.056829  6.303447
# IEMG Historical Data.csv             9.455526             8.932615  6.348983
# IJR Historical Data.csv              7.000553             6.978417  5.696102
# ITB Historical Data.csv              9.392611             9.464621  5.897889
# IVV Historical Data.csv              9.936683            10.000000  6.574308
# IWM Historical Data.csv              8.056680             8.092828  6.227906
# KRE Historical Data.csv              3.161844             3.151125  4.110043
# PSQ Historical Data.csv              0.014514             0.000000  4.062704
# QID Historical Data.csv              0.004297             0.000000  3.638062
# SDOW Historical Data.csv             0.000000             0.067089  2.153519
# SDS Historical Data.csv              0.000000             0.040678  2.766307
# SH Historical Data.csv               0.000000             0.058910  3.072068
# SPXL Historical Data.csv             7.269708             7.329138  5.120205
# SPXS Historical Data.csv             0.000000             0.029636  2.453871
# SPXU Historical Data.csv             0.000000             0.025168  2.447114
# SPY Historical Data.csv              9.944472            10.000000  6.638781
# SRTY Historical Data.csv             0.000000             0.051458  2.012244
# TECS Historical Data.csv             1.148325             1.163174  2.484956
# TNA Historical Data.csv              3.579761             3.607029  3.819942
# TZA Historical Data.csv              0.000000             0.051322  2.001214
# UPRO Historical Data.csv             7.289087             7.351824  5.120549
# USMV Historical Data.csv             7.892043             7.938576  6.527876
# VEA Historical Data.csv              8.355177             8.335518  6.441210
# VWO Historical Data.csv              9.478261             8.963211  6.318718
# XLB Historical Data.csv              9.974565             9.978805  6.768187
# XLE Historical Data.csv              3.095502             3.120489  4.434334
# XLF Historical Data.csv              5.289515             5.273865  5.077602
# XLI Historical Data.csv              8.104348             8.121739  6.030053
# XLK Historical Data.csv              9.775175            10.000000  5.246178
# XLP Historical Data.csv              9.974043             9.974043  6.779029
# XLU Historical Data.csv              4.968632             5.194479  5.781226
# XLV Historical Data.csv              9.747209            10.000000  7.421010
# XOP Historical Data.csv              5.003894             5.013906  5.528772
# XRT Historical Data.csv              9.657187             9.629918  5.660796
#
# Date                      Gap_Mean
# DFEN Historical Data.csv  3.060167
# DIA Historical Data.csv   1.394426
# EEM Historical Data.csv   1.813347
# EFA Historical Data.csv   1.951847
# EWG Historical Data.csv   1.395162
# EWH Historical Data.csv   2.199073
# EWJ Historical Data.csv   1.731403
# EWZ Historical Data.csv   3.311391
# EZU Historical Data.csv   1.994014
# FAS Historical Data.csv   2.894324
# FAZ Historical Data.csv   0.175321
# FXI Historical Data.csv   1.844837
# GDX Historical Data.csv   0.862286
# GDXJ Historical Data.csv  0.403376
# IEFA Historical Data.csv  1.983229
# IEMG Historical Data.csv  1.834258
# IJR Historical Data.csv   2.132167
# ITB Historical Data.csv   0.084661
# IVV Historical Data.csv   0.687201
# IWM Historical Data.csv   1.769889
# KRE Historical Data.csv   3.236240
# PSQ Historical Data.csv   1.152966
# QID Historical Data.csv   1.387022
# SDOW Historical Data.csv  0.259229
# SDS Historical Data.csv   0.320245
# SH Historical Data.csv    0.072073
# SPXL Historical Data.csv  1.872541
# SPXS Historical Data.csv  0.501055
# SPXU Historical Data.csv  0.500762
# SPY Historical Data.csv   0.663661
# SRTY Historical Data.csv  0.007514
# TECS Historical Data.csv  1.191306
# TNA Historical Data.csv   3.014408
# TZA Historical Data.csv   0.000184
# UPRO Historical Data.csv  1.868226
# USMV Historical Data.csv  0.923403
# VEA Historical Data.csv   1.872566
# VWO Historical Data.csv   1.879347
# XLB Historical Data.csv   1.288925
# XLE Historical Data.csv   2.960432
# XLF Historical Data.csv   2.575635
# XLI Historical Data.csv   1.811804
# XLK Historical Data.csv   0.601875
# XLP Historical Data.csv   0.803502
# XLU Historical Data.csv   0.858781
# XLV Historical Data.csv   0.248137
# XOP Historical Data.csv   2.344249
# XRT Historical Data.csv   0.907275
#
# [48 rows x 184 columns]

# %%
# 분석결과 0,1,2,3로 나눠진 군집을 각각 나눠준다.

# 0번 군집(A)
cluster1 = clusters[model.labels_ == 0]
# 1번 군집(B)
cluster2 = clusters[model.labels_ == 1]
# 2번 군집(C)
cluster3 = clusters[model.labels_ == 2]
# 3번 군집(D)
# cluster4 = clusters[model.labels_ == 3]

# %%
# 산점도 그려서 내가 정한 기준(평균 가격, 평균 변동)이 군집을 잘 구분하는지 시각적으로 확인

plt.figure(figsize=(10,10))
plt.scatter(cluster1['Mean'],cluster1['Gap_Mean'], s=100, marker='v', c='r', label = 'A군집')
plt.scatter(cluster2['Mean'],cluster2['Gap_Mean'], s=100, marker='o', c='b', label = 'B군집')
plt.scatter(cluster3['Mean'],cluster3['Gap_Mean'], s=100, marker='s', c='g', label = 'C군집')
# plt.scatter(cluster4['Mean'],cluster4['Gap_Mean'], s=100, marker='x', c='y', label = 'D군집')

plt.xlabel('평균가격', fontsize=14)
plt.ylabel('평균변동량', fontsize=14)

plt.legend()

# B 군집이 좀 지저분하지만, 그래도 적당히 나눠져서 보인다고 판단.
plt.show()

# %%
# 그래프 그리기 위해서 각 군집별 일일 평균 구함.
group0_graph = df2[model.labels_ == 0].transpose()
group0_graph['avg'] = group0_graph.mean(axis=1)
group1_graph = df2[model.labels_ == 1].transpose()
group1_graph['avg'] = group1_graph.mean(axis=1)
group2_graph = df2[model.labels_ == 2].transpose()
group2_graph['avg'] = group2_graph.mean(axis=1)
# group3_graph = df2[model.labels_ == 3].transpose()
# group3_graph['avg'] = group3_graph.mean(axis=1)

# %%
# 군집별로 구한 평균 그래프로 그리기
plt.figure(figsize=(25,15))
plt.plot(group0_graph['avg'], c='r', label = 'A군집')
plt.plot(group1_graph['avg'], c='b', label = 'B군집')
plt.plot(group2_graph['avg'], c='g', label = 'C군집')
# plt.plot(group3_graph['avg'], c='y', label = 'D군집')
plt.legend(prop={'size': 30})

# %% [markdown]
# # 그래프 그리기

# %%
# 2가지 방법이 있음
# 1. (0,1)로 스케일링 된 주가를 다시 역스케일링하여 그래프 그리기 (inverse.transefrom)

# 2. 그냥 스케일링 하기 전의 자료를 가져와서 그리기

# 1번은 각 종목별로 10을 곱하고 이런저런 전처리(Drop 등)를 해서 섞였기 때문에 불가능(거꾸로 되돌려야 해서 어려움)
# 2번, 이전 자료를 가져다가 그래프 그리기

# %%
# 각 클러스터 준비하기

df_cluster1 = pd.DataFrame()
df_cluster2 = pd.DataFrame()
df_cluster3 = pd.DataFrame()
# df_cluster4 = pd.DataFrame()

# %%
# merge 함수를 쓰기 위해 기준 칼럼 생성

df_cluster1['Date'] = etfs_mod[0]['Date']
df_cluster2['Date'] = etfs_mod[0]['Date']
df_cluster3['Date'] = etfs_mod[0]['Date']
# df_cluster4['Date'] = etfs_mod[0]['Date']

# %%
# 각 df_cluster로 해당하는 ETF들 모아서 넣는 함수


for i in range(0,len(file_list)):
    if etfs_mod[i].columns[1] in cluster1.index:
        df_cluster1 = pd.merge(df_cluster1, etfs_mod[i])
    if etfs_mod[i].columns[1] in cluster2.index:
        df_cluster2 = pd.merge(df_cluster2, etfs_mod[i])
    if etfs_mod[i].columns[1] in cluster3.index:
        df_cluster3 = pd.merge(df_cluster3, etfs_mod[i])
    # if etfs_mod[i].columns[1] in cluster4.index:
        # df_cluster4 = pd.merge(df_cluster4, etfs_mod[i])

# %%
# 기타 간단한 처리 및 마무리

df_cluster1.set_index("Date", inplace=True)
df_cluster2.set_index("Date", inplace=True)
df_cluster3.set_index("Date", inplace=True)
# df_cluster4.set_index("Date", inplace=True)

# %%
# A 군집

plt.figure(figsize=(25,15))
for i in range(0,len(df_cluster1.columns)):
    plt.plot(df_cluster1.iloc[:,i], label = df_cluster1.columns[i])

plt.legend(prop={'size': 20})
plt.show()

# %%
# B 군집

plt.figure(figsize=(25,15))
for i in range(0,len(df_cluster2.columns)):
    plt.plot(df_cluster2.iloc[:,i], label = df_cluster2.columns[i])

plt.legend(prop={'size': 20})
plt.show()

# %%
# C 군집

plt.figure(figsize=(25,15))
for i in range(0,len(df_cluster3.columns)):
    plt.plot(df_cluster3.iloc[:,i], label = df_cluster3.columns[i])

plt.legend(prop={'size': 20})
plt.show()

# %%
# 지금은 없어진 D 군집

#plt.figure(figsize=(25,15))
#for i in range(0,len(df_cluster4.columns)):
#    plt.plot(df_cluster4.iloc[:,i], label = df_cluster4.columns[i])

#plt.legend(prop={'size': 20})
#plt.show()

# %%
updown = pd.DataFrame()
updown2 = pd.DataFrame()
updown3 = pd.DataFrame()


for i in range(0, len(df_cluster1.columns)):
    cls = df_cluster1
    temp1 = cls[cls.columns[i]].max()/cls[cls.columns[i]].min()
    temp2 = cls.columns[i]
    updown = updown.append(pd.Series(temp1), ignore_index= True)
    
for i in range(0, len(df_cluster2.columns)):
    cls = df_cluster2
    temp1 = cls[cls.columns[i]].max()/cls[cls.columns[i]].min()
    temp2 = cls.columns[i]
    updown2 = updown2.append(pd.Series(temp1), ignore_index= True)


for i in range(0, len(df_cluster3.columns)):
    cls = df_cluster3
    temp1 = cls[cls.columns[i]].max()/cls[cls.columns[i]].min()
    temp2 = cls.columns[i]
    updown3 = updown3.append(pd.Series(temp1), ignore_index= True)
    
updown.set_index(df_cluster1.columns, inplace=True)
updown2.set_index(df_cluster2.columns, inplace=True)
updown3.set_index(df_cluster3.columns, inplace=True)

# %%
updown3
# Out:
#                                  0
# DIA Historical Data.csv   1.547437
# EEM Historical Data.csv   1.486521
# EFA Historical Data.csv   1.478480
# EWG Historical Data.csv   1.649379
# EWJ Historical Data.csv   1.352928
# EZU Historical Data.csv   1.586542
# FXI Historical Data.csv   1.328125
# GDX Historical Data.csv   2.003501
# GDXJ Historical Data.csv  2.367684
# IEFA Historical Data.csv  1.492551
# IEMG Historical Data.csv  1.502710
# IJR Historical Data.csv   1.706794
# ITB Historical Data.csv   2.262451
# IVV Historical Data.csv   1.524108
# IWM Historical Data.csv   1.669211
# SPY Historical Data.csv   1.529345
# USMV Historical Data.csv  1.444928
# VEA Historical Data.csv   1.512699
# VWO Historical Data.csv   1.482725
# XLB Historical Data.csv   1.583333
# XLI Historical Data.csv   1.678733
# XLK Historical Data.csv   1.721822
# XLP Historical Data.csv   1.300593
# XLV Historical Data.csv   1.388967
# XRT Historical Data.csv   1.924379
